# %%
import numpy as np
import matplotlib.pyplot as plt
import glob, os
import pandas as pd

import scienceplots
plt.style.use(['science', 'notebook', 'grid'])

# %%
folder = "../../build/FullMonaFullmainBulk/**/"
files = glob.glob(
    os.path.join(folder, "mobility_summary.txt")
)
print(f"Found {len(files)} files.")
print("File 0:", files[0])
# Out:
# Found 6 files.
# File 0: ../../build/FullMonaFullmainBulk/Nimp_1e1e15_screened/mobility_summary.txt

# %%
list_D = []
list_mobility = []

print(f"Extracting doping concentration and mobility from {len(files)} files...")
for file in files:
    D = float(file.split("/")[-2].split("_")[1][2:])
    list_D.append(D)
    print(f"Processing file: {file}, D={D:.2e} cm^-3")
    # Read the mobility from the file
    with open(file, "r") as f:
        lines = f.readlines()
        for line in lines:
            print(f"Line: {line.strip()}")
            if line.startswith("low_field_mobility_cm2_per_V_s"):
                mobility = float(line.split("=")[1].strip().split()[0])
                list_mobility.append(mobility)
                print(f"D={D:.2e} cm^-3, mobility={mobility:.2f} cm^2/V/s")
                break
            
# Convert lists to numpy arrays for plotting
D_array = np.array(list_D)
mobility_array = np.array(list_mobility)
argsort = np.argsort(D_array)
D_array = D_array[argsort]
mobility_array = mobility_array[argsort]

fig, ax = plt.subplots()
ax.plot(D_array, mobility_array, marker='o')
ax.set_xlabel("Doping concentration (cm$^{-3}$)")
ax.set_ylabel("Low-field mobility (cm$^2$/V/s)")
ax.set_title("Low-field mobility vs Doping concentration")
ax.set_xscale("log")
plt.show()
# Out:
# Extracting doping concentration and mobility from 6 files...
# Processing file: ../../build/FullMonaFullmainBulk/Nimp_1e1e15_screened/mobility_summary.txt, D=1.00e+15 cm^-3
# Line: low_field_mobility_m2_per_V_s = -1.26680990e-01
# Line: low_field_mobility_cm2_per_V_s = 1.26680990e+03
# D=1.00e+15 cm^-3, mobility=1266.81 cm^2/V/s
# Processing file: ../../build/FullMonaFullmainBulk/Nimp_1e1e16_screened/mobility_summary.txt, D=1.00e+16 cm^-3
# Line: low_field_mobility_m2_per_V_s = -1.05824272e-01
# Line: low_field_mobility_cm2_per_V_s = 1.05824272e+03
# D=1.00e+16 cm^-3, mobility=1058.24 cm^2/V/s
# Processing file: ../../build/FullMonaFullmainBulk/Nimp_1e1e17_screened/mobility_summary.txt, D=1.00e+17 cm^-3
# Line: low_field_mobility_m2_per_V_s = -7.11718068e-02
# Line: low_field_mobility_cm2_per_V_s = 7.11718068e+02
# D=1.00e+17 cm^-3, mobility=711.72 cm^2/V/s
# Processing file: ../../build/FullMonaFullmainBulk/Nimp_1e1e14_screened/mobility_summary.txt, D=1.00e+14 cm^-3
# Line: low_field_mobility_m2_per_V_s = -1.32997307e-01
# Line: low_field_mobility_cm2_per_V_s = 1.32997307e+03
# D=1.00e+14 cm^-3, mobility=1329.97 cm^2/V/s
# Processing file: ../../build/FullMonaFullmainBulk/Nimp_1e1e18_screened/mobility_summary.txt, D=1.00e+18 cm^-3
# Line: low_field_mobility_m2_per_V_s = -3.74058197e-02
# Line: low_field_mobility_cm2_per_V_s = 3.74058197e+02
# D=1.00e+18 cm^-3, mobility=374.06 cm^2/V/s
# Processing file: ../../build/FullMonaFullmainBulk/Nimp_1e3e18_screened/mobility_summary.txt, D=3.00e+18 cm^-3
# Line: low_field_mobility_m2_per_V_s = -2.59540034e-02
# Line: low_field_mobility_cm2_per_V_s = 2.59540034e+02
# D=3.00e+18 cm^-3, mobility=259.54 cm^2/V/s
